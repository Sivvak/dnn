# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Program Operacyjny Polska Cyfrowa na lata 2014-2020
#
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# Code based on https://github.com/pytorch/examples/blob/master/mnist/main.py
#
# This exercise covers two aspects:
#
# - In tasks 1-6 you will implement mechanisms that allow training deeper models (better initialization, batch normalization). Note that for dropout and batch norm you are expected to implement it yourself without relying on ready-made components from Pytorch. After doing each of the tasks you can look at the plots and check how your changes impact gradients of network layers.
# - In task 7 you will implement a convnet using [conv2d](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html).
#
# Tasks:
#
# 1. Check that the given implementation reaches 95% test accuracy for
#    architecture input-64-64-10 in a few thousand batches.
# 2. Improve initialization and check that the network learns much faster
#    and reaches over 97% test accuracy. A good basic initialization scheme is so-called Glorot initialization. For a set of weights going from a layer with $n_{in}$ neurons to a layer with $n_{out}$ neurons, it samples each weight from normal distribution with $0$ mean and standard deviation of $\sqrt{\frac{2}{n_{in}+n_{out}}}$.
#    Check how better initialization changes distribution of gradients at the first epoch.
# 3. Check, that with proper initialization we can train architecture
#    input-64-64-64-64-64-10, while with bad initialization it does
#    not even get off the ground.
# 4. Add dropout implemented in pytorch (but without using torch.nn.Dropout)
# 5. Check that with 10 hidden layers (64 units each) even with proper
#    initialization the network has a hard time to start learning.
# 6. Implement batch normalization (use train mode also for testing - it should perform well enough):
#    - compute batch mean and variance
#    - add new variables beta and gamma
#    - check that the networks learns much faster for 5 layers
#    - check that the network learns even for 10 hidden layers.
#    - check how gradients change in comparison to network without batch norm.
# 7. So far we worked with a fully connected network. Design and implement in pytorch (by using pytorch functions) a simple convolutional network and achieve 99% test accuracy. The architecture is up to you, but even a few convolutional layers should be enough.

# %%
import sys
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn import init
import torchvision
import torchvision.transforms as transforms
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

if "google.colab" in sys.modules:
    from google.colab import output

    output.enable_custom_widget_manager()

# %%
# @title Visualize gradients


class GradientVisualizer:
    def __init__(self, net, num_epochs):
        self.num_epochs = num_epochs
        self.linear_layers = self.get_linear_layers(net)

        self.grad_to_weight_fig = None
        self.grads_in_layers_fig = None
        self.grads_at_epochs_fig = None
        self.init_figures()

    def get_linear_layers(self, net):
        linear_layers = []
        for field in net.__dict__["_modules"].values():
            if isinstance(field, Linear):
                linear_layers.append(field)
            if isinstance(field, nn.ModuleList):
                for module in field:
                    if isinstance(module, Linear):
                        linear_layers.append(module)

        assert linear_layers, (
            "No linear layers found. Linear layers should be parameters of the network or they "
            "should be placed in a ModuleList which is a parameter of the network."
        )
        return linear_layers

    def get_epochs_for_one_layer(self):
        """
        We want to show gradient distributions from up to 7 selected epochs
        for one linear layer.
        """
        if self.num_epochs < 7:
            return list(range(self.num_epochs))
        else:
            return torch.linspace(0, self.num_epochs - 1, 7).int().tolist()

    def get_three_epochs(self):
        """
        We want to show gradients distributions from all layers at each of
        three epochs: first, middle and last.
        """
        return [0, self.num_epochs // 2, self.num_epochs - 1]

    def rgb_to_rgba(self, rgb_color, epoch):
        """
        Value of epoch parameter determines how transparent color should be
        in comparison to others.
        Colors for earlier epochs should be more transparent/less visible.
        """
        return f"rgba{rgb_color[3:-1]},{0.6 * (epoch + 1) / self.num_epochs + 0.15})"

    def init_figures(self):
        # Initialize figure with gradient to weight ratio plot
        fig = go.Figure()
        fig.update_layout(
            title="Gradient standard deviation to weight standard deviation ratio",
            title_x=0.5,
            xaxis_title="Epoch",
            yaxis_title="Gradient to weight ratio (log scale)",
            height=400,
            width=1500,
            margin=dict(b=10, t=60),
        )
        fig.update_yaxes(type="log")
        for i in range(len(self.linear_layers)):
            fig.add_trace(
                go.Scatter(x=[], y=[], mode="lines+markers", name=f"Linear layer {i}")
            )

        self.grad_to_weight_fig = go.FigureWidget(fig)
        display(self.grad_to_weight_fig)

        # Initialize figure visualizing gradient distributions in layers
        num_rows = (len(self.linear_layers) - 1) // 3 + 1
        fig = make_subplots(
            rows=num_rows,
            cols=3,
            subplot_titles=[
                f"Linear layer {i}" for i in range(len(self.linear_layers))
            ],
            vertical_spacing=0.2 / num_rows,
        )
        fig.update_layout(
            title="Comparison between epochs of gradient distributions in layers",
            title_x=0.5,
            height=num_rows * 400,
            width=1500,
            margin=dict(b=10, t=60),
        )

        colors, _ = px.colors.convert_colors_to_same_type(
            2 * px.colors.qualitative.Plotly
        )
        for layer_num in range(len(self.linear_layers)):
            row = layer_num // 3 + 1
            col = layer_num % 3 + 1
            fig.update_xaxes(
                title_text="Gradient value", range=(-0.1, 0.1), row=row, col=col
            )
            fig.update_yaxes(
                title_text="Density (log scale)", type="log", row=row, col=col
            )

            # Create empty traces and update them later with actual gradient distributions.
            # Unfortunately, we cannot add new traces dynamically because Colab has problem
            # with widgets from plotly (traces added dynamically are rendered twice).
            for epoch in self.get_epochs_for_one_layer():
                fig.add_trace(
                    go.Scatter(
                        mode="lines",
                        name=f"Epoch {epoch + 1}",
                        line=dict(color=self.rgb_to_rgba(colors[layer_num], epoch)),
                        legendgroup=layer_num,
                    ),
                    row=row,
                    col=col,
                )

        self.grads_in_layers_fig = go.FigureWidget(fig)
        display(self.grads_in_layers_fig)

        # Initialize figure comparing gradient distributions between layers at the
        # first, middle and last epoch
        selected_epochs_indices = self.get_three_epochs()
        fig = make_subplots(
            rows=1,
            cols=3,
            subplot_titles=[f"Epoch {epoch + 1}" for epoch in selected_epochs_indices],
        )
        fig.update_layout(
            title="Comparison between layers of gradient distributions at epochs",
            title_x=0.5,
            height=400,
            width=1500,
            margin=dict(b=10, t=60),
        )

        for col, epoch in enumerate(selected_epochs_indices, 1):
            fig.update_yaxes(
                title_text="Density (log scale)", type="log", row=1, col=col
            )
            fig.update_xaxes(
                title_text="Gradient value",
                range=(-0.05, 0.05) if epoch != 0 else (-1, 1),
                row=1,
                col=col,
            )

            # Create empty traces and update them later with actual gradient distributions.
            for layer_num in range(len(self.linear_layers)):
                fig.append_trace(
                    go.Scatter(
                        mode="lines",
                        name=f"Linear layer {layer_num}",
                        line=dict(color=colors[layer_num]),
                        showlegend=(col == 1),
                    ),
                    row=1,
                    col=col,
                )

        self.grads_at_epochs_fig = go.FigureWidget(fig)
        display(self.grads_at_epochs_fig)

    def visualize_gradients(self, lr, epoch, batch_idx):
        # It is enough to use gradients calculated for the first batch.
        if batch_idx != 0:
            return

        epoch_grads = []
        epoch_grad_to_weight_ratios = []
        for layer in self.linear_layers:
            epoch_grads.append(layer.weight.grad.flatten().detach())
            epoch_grad_to_weight_ratios.append(
                (lr * layer.weight.grad.std() / layer.weight.std()).item()
            )

        # Update figure with gradient to weight ratio plot
        for i, grad_to_weight_ratio in enumerate(epoch_grad_to_weight_ratios):
            x = self.grad_to_weight_fig.data[i].x
            next_x_val = x[-1] + 1 if x else 1
            self.grad_to_weight_fig.data[i].x += (next_x_val,)
            self.grad_to_weight_fig.data[i].y += (grad_to_weight_ratio,)

        # Update figure visualizing gradient distributions in layers
        selected_epochs = self.get_epochs_for_one_layer()
        if epoch in selected_epochs:
            epoch_idx = selected_epochs.index(epoch)
            for layer_num, layer_grad in enumerate(epoch_grads):
                trace_idx = layer_num * len(selected_epochs) + epoch_idx
                hy, hx = torch.histogram(layer_grad, bins=50, density=True)
                hy = hy / max(hy) + 0.001
                self.grads_in_layers_fig.data[trace_idx].x = hx[:-1].tolist()
                self.grads_in_layers_fig.data[trace_idx].y = hy.tolist()

        # Update figure visualizing gradient distributions at epochs
        selected_epochs = self.get_three_epochs()
        if epoch in selected_epochs:
            epoch_idx = selected_epochs.index(epoch)
            for layer_num, layer_grad in enumerate(epoch_grads):
                trace_idx = epoch_idx * len(self.linear_layers) + layer_num
                hy, hx = torch.histogram(layer_grad, bins=50, density=True)
                hy = hy / max(hy) + 0.001
                self.grads_at_epochs_fig.data[trace_idx].x = hx[:-1].tolist()
                self.grads_at_epochs_fig.data[trace_idx].y = hy.tolist()

# %%
class Linear(torch.nn.Module):
    def __init__(self, in_features, out_features):
        super(Linear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(
            torch.normal(
                mean=0,
                std=math.sqrt(2 / (in_features + out_features)),
                size=(out_features, in_features),
            )
        )
        self.bias = Parameter(torch.Tensor(out_features))
        self.reset_parameters()

    def reset_parameters(self):
        self.weight.data.normal_(mean=0, std=0.25)
        init.zeros_(self.bias)

    def forward(self, x):
        r = x.matmul(self.weight.t())
        r += self.bias
        return r


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = Linear(784, 64)
        self.fc2 = Linear(64, 64)
        self.fc3 = Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class MnistTrainer(object):
    def __init__(self, batch_size):
        transform = transforms.Compose([transforms.ToTensor()])
        self.trainset = torchvision.datasets.MNIST(
            root="./data", download=True, train=True, transform=transform
        )
        self.trainloader = torch.utils.data.DataLoader(
            self.trainset, batch_size=batch_size, shuffle=True, num_workers=2
        )

        self.testset = torchvision.datasets.MNIST(
            root="./data", train=False, download=True, transform=transform
        )
        self.testloader = torch.utils.data.DataLoader(
            self.testset, batch_size=1, shuffle=False, num_workers=2
        )

    def train(self, net, gradient_visualizer, epochs=20, lr=0.05, momentum=0.9):
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)

        for epoch in range(epochs):
            running_loss = 0.0
            for i, data in enumerate(self.trainloader):
                inputs, labels = data
                optimizer.zero_grad()

                outputs = net(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                gradient_visualizer.visualize_gradients(lr, epoch, i)
                optimizer.step()

                running_loss += loss.item()
                if i % 100 == 99:
                    print(
                        "[%d, %5d] loss: %.3f" % (epoch + 1, i + 1, running_loss / 100)
                    )
                    running_loss = 0.0
            correct = 0
            total = 0
            with torch.no_grad():
                for data in self.testloader:
                    images, labels = data
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print(
                "Accuracy of the network on the {} test images: {} %".format(
                    total, 100 * correct / total
                )
            )

# %%
epochs = 20

net = Net()
gradient_visualizer = GradientVisualizer(net, epochs)
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Linear layer 0',
#               'type': 'scatter',
#               'uid': '8c46cf3d-d186-4a9d-b7ee-f9f5de3bbcc2',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 1',
#               'type': 'scatter',
#               'uid': '5ad2413f-f040-499d-bb00-9c6184e8d1f2',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 2',
#               'type': 'scatter',
#               'uid': '9f7ed399-0c74-4183-b9e5-527ea5d3db93',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient standard deviation to weight standard deviation ratio', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Epoch'}},
#                'yaxis': {'title': {'text': 'Gradient to weight ratio (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '491169de-1052-4773-a8c2-059966881ef7',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': 'e197d4dd-dc3b-4aec-975f-c3672c8972be',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '2d1159c0-e6cf-479a-bc89-6f8a80ac6a90',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '8157f684-129d-4cda-b57e-da0cb2735a59',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '4c069cfe-dd4f-446a-87b4-65f3d97304d4',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '9cdf5c07-a12d-4648-ad2c-f5e36a403129',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': 'cdcaa49f-ca25-4f8c-b506-7b32e1aaf3bf',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '92d80ec5-072b-48ed-bd7a-0d2c0eea0d46',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '151ca131-c2b4-4240-925a-3457d00cc991',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '62c9a535-3dc8-4955-9e89-2742911872d5',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '819ae1e4-0b43-4a03-abe9-e985349425ac',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '6f61fbdc-b282-4313-bb13-61aa99b90d1c',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '57871630-cc58-4b84-aca1-0953c3e5f201',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': 'bb78f83e-7992-45b2-b6cb-a10147ba5d84',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '5af268b7-4c9d-46c1-82fc-5668bb368f49',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '7303f826-4ba4-428e-b95b-ec4f3c0ff820',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '9a923f20-97c2-4970-93c3-92ac58689bcd',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '3dafe67a-ebd5-4a34-b521-dec1c36c0c1b',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': 'c24ab247-e564-4a47-a072-ba6b3797cc52',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': 'c1c8e3ce-c50a-43cf-ac75-022e1f3c9f3a',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '800c72cb-a02c-46a2-bdee-53a5be176913',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 0',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 1',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 2',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Comparison between epochs of gradient distributions in layers', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-0.1, 0.1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '609dc08c-860b-4f9b-a9cf-e497b03a82d5',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '859fc57b-bfca-45c6-8032-a1479d96fa6f',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '65c4fba4-94c0-433d-a280-7b2a05aa389a',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '578ed427-2778-46b3-afb5-83829c4b8893',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b8229909-9615-41e1-8026-55fa96c6b6b2',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e5ba7c6c-ab91-4ccd-a1f0-8c9a06f9b869',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '45fa238d-e7d3-4de5-a217-270f85ec4c44',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '21452967-8721-4900-bff0-4fe8c0878f7b',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '18358eab-7177-416c-8bc5-818feffe445e',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 1',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 11',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 20',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Comparison between layers of gradient distributions at epochs', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-1, 1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'}}
# })

# %%
trainer = MnistTrainer(batch_size=128)
trainer.train(net, gradient_visualizer, epochs=epochs)
# Out:
# [1,   100] loss: 0.864
# [1,   200] loss: 0.334
# [1,   300] loss: 0.263
# [1,   400] loss: 0.247
# Accuracy of the network on the 10000 test images: 94.12 %
# [2,   100] loss: 0.181
# [2,   200] loss: 0.170
# [2,   300] loss: 0.173
# [2,   400] loss: 0.168
# Accuracy of the network on the 10000 test images: 95.08 %
# [3,   100] loss: 0.127
# [3,   200] loss: 0.141
# [3,   300] loss: 0.132
# [3,   400] loss: 0.132
# Accuracy of the network on the 10000 test images: 95.9 %
# [4,   100] loss: 0.115
# [4,   200] loss: 0.111
# [4,   300] loss: 0.110
# [4,   400] loss: 0.107
# Accuracy of the network on the 10000 test images: 95.95 %
# [5,   100] loss: 0.087
# [5,   200] loss: 0.094
# [5,   300] loss: 0.092
# [5,   400] loss: 0.105
# Accuracy of the network on the 10000 test images: 95.85 %
# [6,   100] loss: 0.073
# [6,   200] loss: 0.077
# [6,   300] loss: 0.091
# [6,   400] loss: 0.089
# Accuracy of the network on the 10000 test images: 96.28 %
# [7,   100] loss: 0.074
# [7,   200] loss: 0.070
# [7,   300] loss: 0.070
# [7,   400] loss: 0.078
# Accuracy of the network on the 10000 test images: 96.59 %
# [8,   100] loss: 0.057
# [8,   200] loss: 0.060
# [8,   300] loss: 0.063
# [8,   400] loss: 0.076
# Accuracy of the network on the 10000 test images: 96.46 %
# [9,   100] loss: 0.051
# [9,   200] loss: 0.061
# [9,   300] loss: 0.062
# [9,   400] loss: 0.058
# Accuracy of the network on the 10000 test images: 96.62 %
# [10,   100] loss: 0.045
# [10,   200] loss: 0.054
# [10,   300] loss: 0.046
# [10,   400] loss: 0.057
# Accuracy of the network on the 10000 test images: 96.86 %
# [11,   100] loss: 0.043
# [11,   200] loss: 0.060
# [11,   300] loss: 0.046
# [11,   400] loss: 0.047
# Accuracy of the network on the 10000 test images: 96.75 %
# [12,   100] loss: 0.038
# [12,   200] loss: 0.037
# [12,   300] loss: 0.039
# [12,   400] loss: 0.049
# Accuracy of the network on the 10000 test images: 97.0 %
# [13,   100] loss: 0.033
# [13,   200] loss: 0.040
# [13,   300] loss: 0.043
# [13,   400] loss: 0.046
# Accuracy of the network on the 10000 test images: 97.03 %
# [14,   100] loss: 0.028
# [14,   200] loss: 0.034
# [14,   300] loss: 0.040
# [14,   400] loss: 0.039
# Accuracy of the network on the 10000 test images: 97.01 %
# [15,   100] loss: 0.026
# [15,   200] loss: 0.032
# [15,   300] loss: 0.033
# [15,   400] loss: 0.031
# Accuracy of the network on the 10000 test images: 96.91 %
# [16,   100] loss: 0.025
# [16,   200] loss: 0.025
# [16,   300] loss: 0.030
# [16,   400] loss: 0.034
# Accuracy of the network on the 10000 test images: 96.89 %
# [17,   100] loss: 0.024
# [17,   200] loss: 0.025
# [17,   300] loss: 0.027
# [17,   400] loss: 0.028
# Accuracy of the network on the 10000 test images: 96.88 %
# [18,   100] loss: 0.021
# [18,   200] loss: 0.027
# [18,   300] loss: 0.020
# [18,   400] loss: 0.019
# Accuracy of the network on the 10000 test images: 97.05 %
# [19,   100] loss: 0.017
# [19,   200] loss: 0.017
# [19,   300] loss: 0.019
# [19,   400] loss: 0.025
# Accuracy of the network on the 10000 test images: 96.98 %
# [20,   100] loss: 0.016
# [20,   200] loss: 0.019
# [20,   300] loss: 0.017
# [20,   400] loss: 0.020
# Accuracy of the network on the 10000 test images: 97.12 %

# %%
net_task_2 = Net()
gradient_visualizer_task_2 = GradientVisualizer(net_task_2, epochs)
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Linear layer 0',
#               'type': 'scatter',
#               'uid': '74a6c484-4aa5-4991-8a15-ef536ab08376',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 1',
#               'type': 'scatter',
#               'uid': '767b0d3c-058a-4c98-87e5-377526884cd5',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 2',
#               'type': 'scatter',
#               'uid': 'dfb9aea2-fc27-45cb-bacd-ca771ce9e659',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient standard deviation to weight standard deviation ratio', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Epoch'}},
#                'yaxis': {'title': {'text': 'Gradient to weight ratio (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'c626d396-20f5-4502-b8b7-a614913887c2',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '8dbb2f0f-0313-4225-88aa-19dff0728673',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '44a6b626-8b73-49cc-a523-287be56f9371',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': 'fdf442a8-c7b2-4d02-92f3-14fc27ad8bcd',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': 'b2024917-fb5b-4e58-885d-dfe9e99a0af6',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '369da55c-e7d9-445b-b261-26d66d33d0e0',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '7a5acf2b-f29c-41de-97cc-fe984dd02907',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '69f32dad-71a5-467b-bf82-6eeddb3580eb',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': 'a2547676-c859-43d4-8a6e-42acbeca9fbe',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '5a59e462-95f1-4d0d-97c7-7eca788ded45',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '7f56931e-0890-4d82-bc43-db62f7219941',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '7e51e752-4c7c-42c4-9387-3900a990ceb3',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '2ae966ee-87da-45a7-b968-2bc3f079c164',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '00644631-881a-4ef2-b9a2-0de960ca9607',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'ed723700-d0fe-4049-aaf9-f7ae7da01a6c',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': 'efd24f42-fffd-47cd-98fb-9a28a877d016',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '36845c25-6408-4092-b8cf-62b113ab14cd',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '2ec6d715-e2c5-4bcf-a5ae-c2ff9ebca214',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '2fd4fff1-75f7-412f-aa13-d2003a071aee',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '2e56e3fa-344a-477d-9992-3f2da2fafe6d',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': 'db555690-0a56-4fe0-831f-90cabb9a1622',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 0',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 1',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 2',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Comparison between epochs of gradient distributions in layers', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-0.1, 0.1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '52cb14f9-727a-4e07-9c60-8ac52a4a1f14',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '999ff048-8a35-43fe-9edb-b6d9a631be1e',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7576d63b-61cb-4041-90fe-eeb25b9ca804',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3b430230-5547-42b4-94d3-995b22fe0694',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '12cd82ca-c890-4016-a78e-00cca259fb43',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ab278e98-7a94-490d-92fd-4bc8ad153130',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '67839d16-754d-4d71-bac0-cf39dde88bd9',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b3c8f612-e395-4aa6-8129-b47735dc15a0',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a91a02e5-2fab-408e-9f21-f87d4cc35ede',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 1',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 11',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 20',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Comparison between layers of gradient distributions at epochs', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-1, 1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'}}
# })

# %%
trainer = MnistTrainer(batch_size=128)
trainer.train(net_task_2, gradient_visualizer_task_2, epochs=epochs)
# Out:
# [1,   100] loss: 0.951
# [1,   200] loss: 0.356
# [1,   300] loss: 0.301
# [1,   400] loss: 0.261
# Accuracy of the network on the 10000 test images: 93.18 %
# [2,   100] loss: 0.217
# [2,   200] loss: 0.194
# [2,   300] loss: 0.189
# [2,   400] loss: 0.174
# Accuracy of the network on the 10000 test images: 94.23 %
# 609.26s - thread._ident is None in _get_related_thread!
# [3,   100] loss: 0.151
# [3,   200] loss: 0.153
# [3,   300] loss: 0.147
# [3,   400] loss: 0.153
# Accuracy of the network on the 10000 test images: 95.59 %
# 619.07s - thread._ident is None in _get_related_thread!
# [4,   100] loss: 0.117
# [4,   200] loss: 0.128
# [4,   300] loss: 0.120
# [4,   400] loss: 0.129
# Accuracy of the network on the 10000 test images: 95.69 %
# [5,   100] loss: 0.108
# [5,   200] loss: 0.104
# [5,   300] loss: 0.108
# [5,   400] loss: 0.115
# Accuracy of the network on the 10000 test images: 95.95 %
# [6,   100] loss: 0.088
# [6,   200] loss: 0.090
# [6,   300] loss: 0.089
# [6,   400] loss: 0.098
# Accuracy of the network on the 10000 test images: 96.4 %
# [7,   100] loss: 0.080
# [7,   200] loss: 0.090
# [7,   300] loss: 0.084
# [7,   400] loss: 0.086
# Accuracy of the network on the 10000 test images: 96.42 %
# [8,   100] loss: 0.071
# [8,   200] loss: 0.070
# [8,   300] loss: 0.075
# [8,   400] loss: 0.074
# Accuracy of the network on the 10000 test images: 96.44 %
# [9,   100] loss: 0.061
# [9,   200] loss: 0.067
# [9,   300] loss: 0.068
# [9,   400] loss: 0.066
# Accuracy of the network on the 10000 test images: 96.57 %
# [10,   100] loss: 0.051
# [10,   200] loss: 0.054
# [10,   300] loss: 0.058
# [10,   400] loss: 0.061
# Accuracy of the network on the 10000 test images: 96.59 %
# [11,   100] loss: 0.045
# [11,   200] loss: 0.048
# [11,   300] loss: 0.057
# [11,   400] loss: 0.052
# Accuracy of the network on the 10000 test images: 96.8 %
# [12,   100] loss: 0.047
# [12,   200] loss: 0.045
# [12,   300] loss: 0.048
# [12,   400] loss: 0.056
# Accuracy of the network on the 10000 test images: 96.87 %
# [13,   100] loss: 0.038
# [13,   200] loss: 0.040
# [13,   300] loss: 0.046
# [13,   400] loss: 0.047
# Accuracy of the network on the 10000 test images: 96.07 %
# [14,   100] loss: 0.036
# [14,   200] loss: 0.035
# [14,   300] loss: 0.034
# [14,   400] loss: 0.044
# Accuracy of the network on the 10000 test images: 96.79 %
# 729.74s - thread._ident is None in _get_related_thread!
# [15,   100] loss: 0.036
# [15,   200] loss: 0.033
# [15,   300] loss: 0.034
# [15,   400] loss: 0.040
# 733.01s - thread._ident is None in _get_related_thread!
# Accuracy of the network on the 10000 test images: 96.71 %
# [16,   100] loss: 0.028
# [16,   200] loss: 0.030
# [16,   300] loss: 0.038
# [16,   400] loss: 0.044
# Accuracy of the network on the 10000 test images: 96.62 %
# [17,   100] loss: 0.030
# [17,   200] loss: 0.028
# [17,   300] loss: 0.035
# [17,   400] loss: 0.031
# Accuracy of the network on the 10000 test images: 96.69 %
# [18,   100] loss: 0.027
# [18,   200] loss: 0.028
# [18,   300] loss: 0.028
# [18,   400] loss: 0.027
# Accuracy of the network on the 10000 test images: 96.79 %
# [19,   100] loss: 0.025
# [19,   200] loss: 0.027
# [19,   300] loss: 0.027
# [19,   400] loss: 0.031
# Accuracy of the network on the 10000 test images: 96.79 %
# [20,   100] loss: 0.022
# [20,   200] loss: 0.021
# [20,   300] loss: 0.023
# [20,   400] loss: 0.025
# Accuracy of the network on the 10000 test images: 96.57 %
